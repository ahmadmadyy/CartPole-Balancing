# %%
import json
import random
import time
from collections import deque

import gym
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam


class DQNAgent:
    def __init__(self, state_size, action_size):

        self.state_size = state_size
        self.action_size = action_size

        # Initialize Replay Buffer as python deque
        self.replay_buffer = deque(maxlen=40000)

        # Set algorithm hyperparameters
        self.gamma = 0.95
        self.epsilon = 1.
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.98
        self.learning_rate = 0.001
        self.update_rate = 10

        # Create both Main and Target Neural Networks
        self.main_network = self.create_nn()
        self.target_network = self.create_nn()

        # Initialize Target Network with Main Network's weights
        self.target_network.set_weights(self.main_network.get_weights())

    def create_nn(self):
        model = Sequential()

        model.add(Dense(32, activation='relu', input_dim=self.state_size))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))

        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))

        return model

    def update_target_network(self):
        """Method to set the Main NN's weights on the Target NN"""
        self.target_network.set_weights(self.main_network.get_weights())

    def save_experience(self, state, action, reward, next_state, terminal):
        self.replay_buffer.append((state, action, reward, next_state, terminal))

    def sample_experience_batch(self, batch_size):
        # Sample {batchsize} experiences from the Replay Buffer
        exp_batch = random.sample(self.replay_buffer, batch_size)

        # Create an array with the {batchsize} elements for s, a, r, s' and terminal information
        state_batch = np.array([batch[0] for batch in exp_batch]).reshape(batch_size, self.state_size)
        action_batch = np.array([batch[1] for batch in exp_batch])
        reward_batch = [batch[2] for batch in exp_batch]
        next_state_batch = np.array([batch[3] for batch in exp_batch]).reshape(batch_size, self.state_size)
        terminal_batch = [batch[4] for batch in exp_batch]

        # Return a tuple, where each item corresponds to each array/batch created above
        return state_batch, action_batch, reward_batch, next_state_batch, terminal_batch

    def pick_epsilon_greedy_action(self, state):

        # Pick random action with probability ε
        if random.uniform(0, 1) < self.epsilon:
            return np.random.randint(self.action_size)

        # Pick action with highest Q-Value (item with highest value for Main NN's output)
        state = state.reshape((1, self.state_size))
        q_values = self.main_network.predict(state, verbose=0)
        return np.argmax(q_values[0])

    def train(self, batch_size):

        # Sample a batch of experiences
        state_batch, action_batch, reward_batch, next_state_batch, terminal_batch = self.sample_experience_batch(batch_size)

        # Get the actions with highest Q-Value for the batch of next states
        next_q = self.target_network.predict(next_state_batch, verbose=0)
        max_next_q = np.amax(next_q, axis=1)
        # Get the Q-Values of each state in the batch of states
        q_values = self.main_network.predict(state_batch, verbose=0)

        # Update the Q-Value corresponding to the current action with the Target Value
        for i in range(batch_size):
            q_values[i][action_batch[i]] = reward_batch[i] if terminal_batch[i] else reward_batch[i] + self.gamma * max_next_q[i]

        # Fit the Neural Network
        self.main_network.fit(state_batch, q_values, verbose=0)


if __name__ == '__main__':

    # Initialize CartPole environment
    env = gym.make("CartPole-v1")
    state, _ = env.reset()

    # Define state and action size
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # Define number of episodes, timesteps per episode and batch size
    num_episodes = 300
    num_timesteps = 500
    batch_size = 64
    dqn_agent = DQNAgent(state_size, action_size)
    time_step = 0  # Initialize timestep counter, used for updating Target Network
    rewards, epsilon_values = list(), list()  # List to keep logs of rewards and epsilon values, for plotting later

    for ep in range(num_episodes):

        tot_reward = 0

        state, _ = env.reset()

        print(f'\nTraining on EPISODE {ep+1} with epsilon {dqn_agent.epsilon}')
        start = time.time()

        for t in range(num_timesteps):

            time_step += 1

            # Update Target Network every {dqn_agent.update_rate} timesteps
            if time_step % dqn_agent.update_rate == 0:
                dqn_agent.update_target_network()

            action = dqn_agent.pick_epsilon_greedy_action(state)  # Select action with ε-greedy policy
            next_state, reward, terminal, _, _ = env.step(action)  # Perform action on environment
            dqn_agent.save_experience(state, action, reward, next_state, terminal)  # Save experience in Replay Buffer

            # Update current state to next state and total reward
            state = next_state
            tot_reward += reward

            if terminal:
                print('Episode: ', ep+1, ',' ' terminated with Reward ', tot_reward)
                break

            # Train the Main NN when ReplayBuffer has enough experiences to fill a batch
            if len(dqn_agent.replay_buffer) > batch_size:
                dqn_agent.train(batch_size)

        rewards.append(tot_reward)
        epsilon_values.append(dqn_agent.epsilon)

        # Everytime an episode ends, update Epsilon value to a lower value
        if dqn_agent.epsilon > dqn_agent.epsilon_min:
            dqn_agent.epsilon *= dqn_agent.epsilon_decay

        # Print info about the episode performed
        elapsed = time.time() - start
        print(f'Time elapsed during EPISODE {ep+1}: {elapsed} seconds = {round(elapsed/60, 3)} minutes')

        # If the agent got a reward >499 in each of the last 10 episodes, the training is terminated
        if sum(rewards[-10:]) > 4990:
            print('Training stopped because agent has performed a perfect episode in the last 10 episodes')
            break

    # Save rewards on 'rewards.txt' file
    with open('rewards.txt', 'w') as f:
        f.write(json.dumps(rewards))
    print("Rewards of the training saved in 'rewards.txt'")

    # Save epsilon values
    with open('epsilon_values.txt', 'w') as f:
        f.write(json.dumps(epsilon_values))
    print("Epsilon values of the training saved in 'epsilon_values.txt'")

    # Save trained model
    dqn_agent.main_network.save('trained_agent.h5')
    print("Trained agent saved in 'trained_agent.h5'")
# Out:
# Training on EPISODE 1 with epsilon 1.0
# Episode:  1 , terminated with Reward  17.0
# Time elapsed during EPISODE 1: 0.03960609436035156 seconds = 0.001 minutes
#
# Training on EPISODE 2 with epsilon 0.98
# Episode:  2 , terminated with Reward  12.0
# Time elapsed during EPISODE 2: 0.013025760650634766 seconds = 0.0 minutes
#
# Training on EPISODE 3 with epsilon 0.9603999999999999
# Episode:  3 , terminated with Reward  11.0
# Time elapsed during EPISODE 3: 1.3406593799591064 seconds = 0.022 minutes
#
# Training on EPISODE 4 with epsilon 0.9411919999999999
# Episode:  4 , terminated with Reward  11.0
# Time elapsed during EPISODE 4: 0.17226600646972656 seconds = 0.003 minutes
#
# Training on EPISODE 5 with epsilon 0.9223681599999999
# Episode:  5 , terminated with Reward  14.0
# Time elapsed during EPISODE 5: 0.224717378616333 seconds = 0.004 minutes
#
# Training on EPISODE 6 with epsilon 0.9039207967999998
# Episode:  6 , terminated with Reward  9.0
# Time elapsed during EPISODE 6: 6.944778680801392 seconds = 0.116 minutes
#
# Training on EPISODE 7 with epsilon 0.8858423808639998
# Episode:  7 , terminated with Reward  14.0
# Time elapsed during EPISODE 7: 5.9982750415802 seconds = 0.1 minutes
#
# Training on EPISODE 8 with epsilon 0.8681255332467198
# Episode:  8 , terminated with Reward  13.0
# Time elapsed during EPISODE 8: 5.390562534332275 seconds = 0.09 minutes
#
# Training on EPISODE 9 with epsilon 0.8507630225817854
# Episode:  9 , terminated with Reward  21.0
# Time elapsed during EPISODE 9: 8.859959363937378 seconds = 0.148 minutes
#
# Training on EPISODE 10 with epsilon 0.8337477621301497
# Episode:  10 , terminated with Reward  41.0
# Time elapsed during EPISODE 10: 19.578956604003906 seconds = 0.326 minutes
#
# Training on EPISODE 11 with epsilon 0.8170728068875467
# Episode:  11 , terminated with Reward  24.0
# Time elapsed during EPISODE 11: 10.068385601043701 seconds = 0.168 minutes
#
# Training on EPISODE 12 with epsilon 0.8007313507497957
# Episode:  12 , terminated with Reward  15.0
# Time elapsed during EPISODE 12: 5.393178462982178 seconds = 0.09 minutes
#
# Training on EPISODE 13 with epsilon 0.7847167237347998
# Episode:  13 , terminated with Reward  52.0
# Time elapsed during EPISODE 13: 23.133176803588867 seconds = 0.386 minutes
#
# Training on EPISODE 14 with epsilon 0.7690223892601038
# Episode:  14 , terminated with Reward  27.0
# Time elapsed during EPISODE 14: 11.60002851486206 seconds = 0.193 minutes
#
# Training on EPISODE 15 with epsilon 0.7536419414749017
# Episode:  15 , terminated with Reward  48.0
# Time elapsed during EPISODE 15: 19.86569619178772 seconds = 0.331 minutes
#
# Training on EPISODE 16 with epsilon 0.7385691026454037
# Episode:  16 , terminated with Reward  17.0
# Time elapsed during EPISODE 16: 7.671851396560669 seconds = 0.128 minutes
#
# Training on EPISODE 17 with epsilon 0.7237977205924956
# Episode:  17 , terminated with Reward  15.0
# Time elapsed during EPISODE 17: 5.267033338546753 seconds = 0.088 minutes
#
# Training on EPISODE 18 with epsilon 0.7093217661806457
# Episode:  18 , terminated with Reward  57.0
# Time elapsed during EPISODE 18: 25.04140853881836 seconds = 0.417 minutes
#
# Training on EPISODE 19 with epsilon 0.6951353308570327
# Episode:  19 , terminated with Reward  18.0
# Time elapsed during EPISODE 19: 7.10006046295166 seconds = 0.118 minutes
#
# Training on EPISODE 20 with epsilon 0.6812326242398921
# Episode:  20 , terminated with Reward  21.0
# Time elapsed during EPISODE 20: 9.045505285263062 seconds = 0.151 minutes
#
# Training on EPISODE 21 with epsilon 0.6676079717550942
# Episode:  21 , terminated with Reward  22.0
# Time elapsed during EPISODE 21: 9.040889024734497 seconds = 0.151 minutes
#
# Training on EPISODE 22 with epsilon 0.6542558123199923
# Episode:  22 , terminated with Reward  141.0
# Time elapsed during EPISODE 22: 57.85148572921753 seconds = 0.964 minutes
#
# Training on EPISODE 23 with epsilon 0.6411706960735924
# Episode:  23 , terminated with Reward  13.0
# Time elapsed during EPISODE 23: 4.822166681289673 seconds = 0.08 minutes
#
# Training on EPISODE 24 with epsilon 0.6283472821521205
# Episode:  24 , terminated with Reward  123.0
# Time elapsed during EPISODE 24: 49.31205606460571 seconds = 0.822 minutes
#
# Training on EPISODE 25 with epsilon 0.6157803365090782
# Episode:  25 , terminated with Reward  130.0
# Time elapsed during EPISODE 25: 52.471890926361084 seconds = 0.875 minutes
#
# Training on EPISODE 26 with epsilon 0.6034647297788965
# Episode:  26 , terminated with Reward  85.0
# Time elapsed during EPISODE 26: 34.43764877319336 seconds = 0.574 minutes
#
# Training on EPISODE 27 with epsilon 0.5913954351833186
# Episode:  27 , terminated with Reward  24.0
# Time elapsed during EPISODE 27: 10.313865900039673 seconds = 0.172 minutes
#
# Training on EPISODE 28 with epsilon 0.5795675264796523
# Episode:  28 , terminated with Reward  37.0
# Time elapsed during EPISODE 28: 13.817942142486572 seconds = 0.23 minutes
#
# Training on EPISODE 29 with epsilon 0.5679761759500592
# Episode:  29 , terminated with Reward  57.0
# Time elapsed during EPISODE 29: 21.721009492874146 seconds = 0.362 minutes
#
# Training on EPISODE 30 with epsilon 0.5566166524310581
# Episode:  30 , terminated with Reward  32.0
# Time elapsed during EPISODE 30: 13.6128249168396 seconds = 0.227 minutes
#
# Training on EPISODE 31 with epsilon 0.5454843193824369
# Episode:  31 , terminated with Reward  21.0
# Time elapsed during EPISODE 31: 7.520291090011597 seconds = 0.125 minutes
#
# Training on EPISODE 32 with epsilon 0.5345746329947881
# Episode:  32 , terminated with Reward  115.0
# Time elapsed during EPISODE 32: 48.429349184036255 seconds = 0.807 minutes
#
# Training on EPISODE 33 with epsilon 0.5238831403348924
# Episode:  33 , terminated with Reward  33.0
# Time elapsed during EPISODE 33: 13.340460300445557 seconds = 0.222 minutes
#
# Training on EPISODE 34 with epsilon 0.5134054775281945
# Episode:  34 , terminated with Reward  39.0
# Time elapsed during EPISODE 34: 16.4444739818573 seconds = 0.274 minutes
#
# Training on EPISODE 35 with epsilon 0.5031373679776306
# Episode:  35 , terminated with Reward  45.0
# Time elapsed during EPISODE 35: 20.43646764755249 seconds = 0.341 minutes
#
# Training on EPISODE 36 with epsilon 0.493074620618078
# Episode:  36 , terminated with Reward  13.0
# Time elapsed during EPISODE 36: 5.669381856918335 seconds = 0.094 minutes
#
# Training on EPISODE 37 with epsilon 0.48321312820571644
# Episode:  37 , terminated with Reward  127.0
# Time elapsed during EPISODE 37: 51.16156220436096 seconds = 0.853 minutes
#
# Training on EPISODE 38 with epsilon 0.4735488656416021
# Episode:  38 , terminated with Reward  47.0
# Time elapsed during EPISODE 38: 18.60377550125122 seconds = 0.31 minutes
#
# Training on EPISODE 39 with epsilon 0.46407788832877006
# Episode:  39 , terminated with Reward  52.0
# Time elapsed during EPISODE 39: 21.500689268112183 seconds = 0.358 minutes
#
# Training on EPISODE 40 with epsilon 0.45479633056219465
# Episode:  40 , terminated with Reward  98.0
# Time elapsed during EPISODE 40: 44.4780547618866 seconds = 0.741 minutes
#
# Training on EPISODE 41 with epsilon 0.44570040395095073
# Episode:  41 , terminated with Reward  24.0
# Time elapsed during EPISODE 41: 10.734417200088501 seconds = 0.179 minutes
#
# Training on EPISODE 42 with epsilon 0.4367863958719317
# Episode:  42 , terminated with Reward  70.0
# Time elapsed during EPISODE 42: 30.892014980316162 seconds = 0.515 minutes
#
# Training on EPISODE 43 with epsilon 0.42805066795449304
# Episode:  43 , terminated with Reward  133.0
# Time elapsed during EPISODE 43: 57.62283658981323 seconds = 0.96 minutes
#
# Training on EPISODE 44 with epsilon 0.41948965459540316
# Episode:  44 , terminated with Reward  48.0
# Time elapsed during EPISODE 44: 20.189002513885498 seconds = 0.336 minutes
#
# Training on EPISODE 45 with epsilon 0.4110998615034951
# Episode:  45 , terminated with Reward  22.0
# Time elapsed during EPISODE 45: 7.867462873458862 seconds = 0.131 minutes
#
# Training on EPISODE 46 with epsilon 0.4028778642734252
# Episode:  46 , terminated with Reward  22.0
# Time elapsed during EPISODE 46: 9.46291995048523 seconds = 0.158 minutes
#
# Training on EPISODE 47 with epsilon 0.39482030698795667
# Episode:  47 , terminated with Reward  163.0
# Time elapsed during EPISODE 47: 74.79758548736572 seconds = 1.247 minutes
#
# Training on EPISODE 48 with epsilon 0.38692390084819756
# Episode:  48 , terminated with Reward  29.0
# Time elapsed during EPISODE 48: 12.938905954360962 seconds = 0.216 minutes
#
# Training on EPISODE 49 with epsilon 0.3791854228312336
# Episode:  49 , terminated with Reward  14.0
# Time elapsed during EPISODE 49: 5.916642427444458 seconds = 0.099 minutes
#
# Training on EPISODE 50 with epsilon 0.37160171437460887
# Episode:  50 , terminated with Reward  168.0
# Time elapsed during EPISODE 50: 75.09678649902344 seconds = 1.252 minutes
#
# Training on EPISODE 51 with epsilon 0.3641696800871167
# Episode:  51 , terminated with Reward  272.0
# Time elapsed during EPISODE 51: 115.19100427627563 seconds = 1.92 minutes
#
# Training on EPISODE 52 with epsilon 0.35688628648537435
# Episode:  52 , terminated with Reward  146.0
# Time elapsed during EPISODE 52: 63.78261709213257 seconds = 1.063 minutes
#
# Training on EPISODE 53 with epsilon 0.34974856075566685
# Episode:  53 , terminated with Reward  104.0
# Time elapsed during EPISODE 53: 43.419074058532715 seconds = 0.724 minutes
#
# Training on EPISODE 54 with epsilon 0.3427535895405535
# Episode:  54 , terminated with Reward  77.0
# Time elapsed during EPISODE 54: 33.349876403808594 seconds = 0.556 minutes
#
# Training on EPISODE 55 with epsilon 0.33589851774974244
# Episode:  55 , terminated with Reward  133.0
# Time elapsed during EPISODE 55: 55.72725987434387 seconds = 0.929 minutes
#
# Training on EPISODE 56 with epsilon 0.3291805473947476
# Episode:  56 , terminated with Reward  75.0
# Time elapsed during EPISODE 56: 31.75483465194702 seconds = 0.529 minutes
#
# Training on EPISODE 57 with epsilon 0.32259693644685267
# Episode:  57 , terminated with Reward  67.0
# Time elapsed during EPISODE 57: 27.62418842315674 seconds = 0.46 minutes
#
# Training on EPISODE 58 with epsilon 0.3161449977179156
# Episode:  58 , terminated with Reward  148.0
# Time elapsed during EPISODE 58: 63.5672447681427 seconds = 1.059 minutes
#
# Training on EPISODE 59 with epsilon 0.3098220977635573
# Episode:  59 , terminated with Reward  66.0
# Time elapsed during EPISODE 59: 27.440082550048828 seconds = 0.457 minutes
#
# Training on EPISODE 60 with epsilon 0.30362565580828615
# Episode:  60 , terminated with Reward  180.0
# Time elapsed during EPISODE 60: 76.36549496650696 seconds = 1.273 minutes
#
# Training on EPISODE 61 with epsilon 0.2975531426921204
# Episode:  61 , terminated with Reward  13.0
# Time elapsed during EPISODE 61: 5.03385853767395 seconds = 0.084 minutes
#
# Training on EPISODE 62 with epsilon 0.291602079838278
# Episode:  62 , terminated with Reward  233.0
# Time elapsed during EPISODE 62: 100.46282315254211 seconds = 1.674 minutes
#
# Training on EPISODE 63 with epsilon 0.2857700382415124
# Episode:  63 , terminated with Reward  316.0
# Time elapsed during EPISODE 63: 139.82982754707336 seconds = 2.33 minutes
#
# Training on EPISODE 64 with epsilon 0.2800546374766822
# Episode:  64 , terminated with Reward  17.0
# Time elapsed during EPISODE 64: 7.409003496170044 seconds = 0.123 minutes
#
# Training on EPISODE 65 with epsilon 0.27445354472714856
# Episode:  65 , terminated with Reward  28.0
# Time elapsed during EPISODE 65: 11.559203624725342 seconds = 0.193 minutes
#
# Training on EPISODE 66 with epsilon 0.2689644738326056
# Episode:  66 , terminated with Reward  27.0
# Time elapsed during EPISODE 66: 11.432083368301392 seconds = 0.191 minutes
#
# Training on EPISODE 67 with epsilon 0.26358518435595346
# Episode:  67 , terminated with Reward  28.0
# Time elapsed during EPISODE 67: 11.280243396759033 seconds = 0.188 minutes
#
# Training on EPISODE 68 with epsilon 0.25831348066883436
# Episode:  68 , terminated with Reward  49.0
# Time elapsed during EPISODE 68: 20.707762241363525 seconds = 0.345 minutes
#
# Training on EPISODE 69 with epsilon 0.2531472110554577
# Episode:  69 , terminated with Reward  230.0
# Time elapsed during EPISODE 69: 101.76170015335083 seconds = 1.696 minutes
#
# Training on EPISODE 70 with epsilon 0.24808426683434853
# Episode:  70 , terminated with Reward  146.0
# Time elapsed during EPISODE 70: 62.643441677093506 seconds = 1.044 minutes
#
# Training on EPISODE 71 with epsilon 0.24312258149766156
# Episode:  71 , terminated with Reward  48.0
# Time elapsed during EPISODE 71: 21.88097310066223 seconds = 0.365 minutes
#
# Training on EPISODE 72 with epsilon 0.2382601298677083
# Episode:  72 , terminated with Reward  22.0
# Time elapsed during EPISODE 72: 9.8158278465271 seconds = 0.164 minutes
#
# Training on EPISODE 73 with epsilon 0.23349492727035415
# Episode:  73 , terminated with Reward  153.0
# Time elapsed during EPISODE 73: 66.4597520828247 seconds = 1.108 minutes
#
# Training on EPISODE 74 with epsilon 0.22882502872494706
# Episode:  74 , terminated with Reward  19.0
# Time elapsed during EPISODE 74: 7.798303842544556 seconds = 0.13 minutes
#
# Training on EPISODE 75 with epsilon 0.22424852815044813
# Episode:  75 , terminated with Reward  156.0
# Time elapsed during EPISODE 75: 68.55161786079407 seconds = 1.143 minutes
#
# Training on EPISODE 76 with epsilon 0.21976355758743915
# Episode:  76 , terminated with Reward  11.0
# Time elapsed during EPISODE 76: 4.124309778213501 seconds = 0.069 minutes
#
# Training on EPISODE 77 with epsilon 0.21536828643569036
# Episode:  77 , terminated with Reward  71.0
# Time elapsed during EPISODE 77: 31.300191402435303 seconds = 0.522 minutes
#
# Training on EPISODE 78 with epsilon 0.21106092070697655
# Episode:  78 , terminated with Reward  24.0
# Time elapsed during EPISODE 78: 10.063159227371216 seconds = 0.168 minutes
#
# Training on EPISODE 79 with epsilon 0.20683970229283702
# Episode:  79 , terminated with Reward  67.0
# Time elapsed during EPISODE 79: 30.069243669509888 seconds = 0.501 minutes
#
# Training on EPISODE 80 with epsilon 0.20270290824698028
# Episode:  80 , terminated with Reward  104.0
# Time elapsed during EPISODE 80: 55.57789349555969 seconds = 0.926 minutes
#
# Training on EPISODE 81 with epsilon 0.19864885008204067
# Episode:  81 , terminated with Reward  128.0
# Time elapsed during EPISODE 81: 68.7860643863678 seconds = 1.146 minutes
#
# Training on EPISODE 82 with epsilon 0.19467587308039985
# Episode:  82 , terminated with Reward  66.0
# Time elapsed during EPISODE 82: 35.18986535072327 seconds = 0.586 minutes
#
# Training on EPISODE 83 with epsilon 0.19078235561879187
# Episode:  83 , terminated with Reward  139.0
# Time elapsed during EPISODE 83: 74.17887926101685 seconds = 1.236 minutes
#
# Training on EPISODE 84 with epsilon 0.18696670850641603
# Episode:  84 , terminated with Reward  135.0
# Time elapsed during EPISODE 84: 73.72933387756348 seconds = 1.229 minutes
#
# Training on EPISODE 85 with epsilon 0.18322737433628772
# Episode:  85 , terminated with Reward  122.0
# Time elapsed during EPISODE 85: 66.02783441543579 seconds = 1.1 minutes
#
# Training on EPISODE 86 with epsilon 0.17956282684956196
# Episode:  86 , terminated with Reward  217.0
# Time elapsed during EPISODE 86: 117.2413718700409 seconds = 1.954 minutes
#
# Training on EPISODE 87 with epsilon 0.1759715703125707
# Episode:  87 , terminated with Reward  114.0
# Time elapsed during EPISODE 87: 60.1773316860199 seconds = 1.003 minutes
#
# Training on EPISODE 88 with epsilon 0.1724521389063193
# Episode:  88 , terminated with Reward  79.0
# Time elapsed during EPISODE 88: 45.30443835258484 seconds = 0.755 minutes
#
# Training on EPISODE 89 with epsilon 0.16900309612819292
# Episode:  89 , terminated with Reward  65.0
# Time elapsed during EPISODE 89: 34.41812777519226 seconds = 0.574 minutes
#
# Training on EPISODE 90 with epsilon 0.16562303420562907
# Episode:  90 , terminated with Reward  113.0
# Time elapsed during EPISODE 90: 61.649362564086914 seconds = 1.027 minutes
#
# Training on EPISODE 91 with epsilon 0.16231057352151648
# Episode:  91 , terminated with Reward  59.0
# Time elapsed during EPISODE 91: 32.33699917793274 seconds = 0.539 minutes
#
# Training on EPISODE 92 with epsilon 0.15906436205108615
# Episode:  92 , terminated with Reward  151.0
# Time elapsed during EPISODE 92: 82.61669921875 seconds = 1.377 minutes
#
# Training on EPISODE 93 with epsilon 0.15588307481006441
# Episode:  93 , terminated with Reward  27.0
# Time elapsed during EPISODE 93: 13.925411224365234 seconds = 0.232 minutes
#
# Training on EPISODE 94 with epsilon 0.15276541331386312
# Episode:  94 , terminated with Reward  15.0
# Time elapsed during EPISODE 94: 6.80557107925415 seconds = 0.113 minutes
#
# Training on EPISODE 95 with epsilon 0.14971010504758586
# Episode:  95 , terminated with Reward  136.0
# Time elapsed during EPISODE 95: 70.88646173477173 seconds = 1.181 minutes
#
# Training on EPISODE 96 with epsilon 0.14671590294663414
# Episode:  96 , terminated with Reward  149.0
# Time elapsed during EPISODE 96: 84.37405705451965 seconds = 1.406 minutes
#
# Training on EPISODE 97 with epsilon 0.14378158488770146
# Episode:  97 , terminated with Reward  125.0
# Time elapsed during EPISODE 97: 68.13941287994385 seconds = 1.136 minutes
#
# Training on EPISODE 98 with epsilon 0.14090595318994742
# Episode:  98 , terminated with Reward  119.0
# Time elapsed during EPISODE 98: 62.528411865234375 seconds = 1.042 minutes
#
# Training on EPISODE 99 with epsilon 0.13808783412614847
# Episode:  99 , terminated with Reward  77.0
# Time elapsed during EPISODE 99: 39.77022194862366 seconds = 0.663 minutes
#
# Training on EPISODE 100 with epsilon 0.13532607744362551
# Episode:  100 , terminated with Reward  114.0
# Time elapsed during EPISODE 100: 66.6830325126648 seconds = 1.111 minutes
#
# Training on EPISODE 101 with epsilon 0.132619555894753
# Episode:  101 , terminated with Reward  368.0
# Time elapsed during EPISODE 101: 211.44810390472412 seconds = 3.524 minutes
#
# Training on EPISODE 102 with epsilon 0.12996716477685794
# Episode:  102 , terminated with Reward  29.0
# Time elapsed during EPISODE 102: 15.463054418563843 seconds = 0.258 minutes
#
# Training on EPISODE 103 with epsilon 0.12736782148132078
# Episode:  103 , terminated with Reward  113.0
# Time elapsed during EPISODE 103: 59.67010498046875 seconds = 0.995 minutes
#
# Training on EPISODE 104 with epsilon 0.12482046505169436
# Episode:  104 , terminated with Reward  221.0
# Time elapsed during EPISODE 104: 110.66415858268738 seconds = 1.844 minutes
#
# Training on EPISODE 105 with epsilon 0.12232405575066048
# Episode:  105 , terminated with Reward  137.0
# Time elapsed during EPISODE 105: 80.03629183769226 seconds = 1.334 minutes
#
# Training on EPISODE 106 with epsilon 0.11987757463564727
# Episode:  106 , terminated with Reward  232.0
# Time elapsed during EPISODE 106: 128.76587414741516 seconds = 2.146 minutes
#
# Training on EPISODE 107 with epsilon 0.11748002314293432
# Episode:  107 , terminated with Reward  190.0
# Time elapsed during EPISODE 107: 104.9745283126831 seconds = 1.75 minutes
#
# Training on EPISODE 108 with epsilon 0.11513042268007563
# Episode:  108 , terminated with Reward  184.0
# Time elapsed during EPISODE 108: 100.1367781162262 seconds = 1.669 minutes
#
# Training on EPISODE 109 with epsilon 0.11282781422647412
# Episode:  109 , terminated with Reward  185.0
# Time elapsed during EPISODE 109: 109.29110789299011 seconds = 1.822 minutes
#
# Training on EPISODE 110 with epsilon 0.11057125794194463
# Episode:  110 , terminated with Reward  139.0
# Time elapsed during EPISODE 110: 76.70606088638306 seconds = 1.278 minutes
#
# Training on EPISODE 111 with epsilon 0.10835983278310574
# Episode:  111 , terminated with Reward  128.0
# Time elapsed during EPISODE 111: 71.20270657539368 seconds = 1.187 minutes
#
# Training on EPISODE 112 with epsilon 0.10619263612744362
# Episode:  112 , terminated with Reward  113.0
# Time elapsed during EPISODE 112: 57.85847187042236 seconds = 0.964 minutes
#
# Training on EPISODE 113 with epsilon 0.10406878340489474
# Episode:  113 , terminated with Reward  224.0
# Time elapsed during EPISODE 113: 105.42640352249146 seconds = 1.757 minutes
#
# Training on EPISODE 114 with epsilon 0.10198740773679685
# Episode:  114 , terminated with Reward  221.0
# Time elapsed during EPISODE 114: 105.70900630950928 seconds = 1.762 minutes
#
# Training on EPISODE 115 with epsilon 0.09994765958206091
# Episode:  115 , terminated with Reward  335.0
# Time elapsed during EPISODE 115: 158.15514755249023 seconds = 2.636 minutes
#
# Training on EPISODE 116 with epsilon 0.0979487063904197
# Episode:  116 , terminated with Reward  161.0
# Time elapsed during EPISODE 116: 76.46314311027527 seconds = 1.274 minutes
#
# Training on EPISODE 117 with epsilon 0.0959897322626113
# Episode:  117 , terminated with Reward  292.0
# Time elapsed during EPISODE 117: 140.73314666748047 seconds = 2.346 minutes
#
# Training on EPISODE 118 with epsilon 0.09406993761735907
# Episode:  118 , terminated with Reward  180.0
# Time elapsed during EPISODE 118: 85.15451550483704 seconds = 1.419 minutes
#
# Training on EPISODE 119 with epsilon 0.0921885388650119
# Episode:  119 , terminated with Reward  118.0
# Time elapsed during EPISODE 119: 56.372472286224365 seconds = 0.94 minutes
#
# Training on EPISODE 120 with epsilon 0.09034476808771166
# Episode:  120 , terminated with Reward  103.0
# Time elapsed during EPISODE 120: 50.09665036201477 seconds = 0.835 minutes
#
# Training on EPISODE 121 with epsilon 0.08853787272595742
# Episode:  121 , terminated with Reward  164.0
# Time elapsed during EPISODE 121: 78.34969091415405 seconds = 1.306 minutes
#
# Training on EPISODE 122 with epsilon 0.08676711527143827
# Episode:  122 , terminated with Reward  322.0
# Time elapsed during EPISODE 122: 154.67101979255676 seconds = 2.578 minutes
#
# Training on EPISODE 123 with epsilon 0.0850317729660095
# Time elapsed during EPISODE 123: 241.08439421653748 seconds = 4.018 minutes
#
# Training on EPISODE 124 with epsilon 0.08333113750668932
# Episode:  124 , terminated with Reward  385.0
# Time elapsed during EPISODE 124: 183.67202758789062 seconds = 3.061 minutes
#
# Training on EPISODE 125 with epsilon 0.08166451475655553
# Episode:  125 , terminated with Reward  211.0
# Time elapsed during EPISODE 125: 101.14882755279541 seconds = 1.686 minutes
#
# Training on EPISODE 126 with epsilon 0.08003122446142442
# Episode:  126 , terminated with Reward  116.0
# Time elapsed during EPISODE 126: 65.515793800354 seconds = 1.092 minutes
#
# Training on EPISODE 127 with epsilon 0.07843059997219594
# Episode:  127 , terminated with Reward  195.0
# Time elapsed during EPISODE 127: 115.54996824264526 seconds = 1.926 minutes
#
# Training on EPISODE 128 with epsilon 0.07686198797275202
# Episode:  128 , terminated with Reward  336.0
# Time elapsed during EPISODE 128: 192.90471506118774 seconds = 3.215 minutes
#
# Training on EPISODE 129 with epsilon 0.07532474821329699
# Episode:  129 , terminated with Reward  251.0
# Time elapsed during EPISODE 129: 145.67492985725403 seconds = 2.428 minutes
#
# Training on EPISODE 130 with epsilon 0.07381825324903105
# Episode:  130 , terminated with Reward  205.0
# Time elapsed during EPISODE 130: 133.68108248710632 seconds = 2.228 minutes
#
# Training on EPISODE 131 with epsilon 0.07234188818405042
# Episode:  131 , terminated with Reward  293.0
# Time elapsed during EPISODE 131: 196.45717477798462 seconds = 3.274 minutes
#
# Training on EPISODE 132 with epsilon 0.07089505042036941
# Episode:  132 , terminated with Reward  142.0
# Time elapsed during EPISODE 132: 94.44358563423157 seconds = 1.574 minutes
#
# Training on EPISODE 133 with epsilon 0.06947714941196202
# Episode:  133 , terminated with Reward  192.0
# Time elapsed during EPISODE 133: 119.93550229072571 seconds = 1.999 minutes
#
# Training on EPISODE 134 with epsilon 0.06808760642372277
# Episode:  134 , terminated with Reward  266.0
# Time elapsed during EPISODE 134: 173.87801241874695 seconds = 2.898 minutes
#
# Training on EPISODE 135 with epsilon 0.06672585429524831
# Episode:  135 , terminated with Reward  225.0
# Time elapsed during EPISODE 135: 121.6482834815979 seconds = 2.027 minutes
#
# Training on EPISODE 136 with epsilon 0.06539133720934334
# Episode:  136 , terminated with Reward  130.0
# Time elapsed during EPISODE 136: 70.44973754882812 seconds = 1.174 minutes
#
# Training on EPISODE 137 with epsilon 0.06408351046515648
# Time elapsed during EPISODE 137: 264.74042654037476 seconds = 4.412 minutes
#
# Training on EPISODE 138 with epsilon 0.06280184025585335
# Episode:  138 , terminated with Reward  400.0
# Time elapsed during EPISODE 138: 248.49018502235413 seconds = 4.142 minutes
#
# Training on EPISODE 139 with epsilon 0.061545803450736285
# Episode:  139 , terminated with Reward  262.0
# Time elapsed during EPISODE 139: 165.21205353736877 seconds = 2.754 minutes
#
# Training on EPISODE 140 with epsilon 0.060314887381721555
# Episode:  140 , terminated with Reward  204.0
# Time elapsed during EPISODE 140: 136.56814098358154 seconds = 2.276 minutes
#
# Training on EPISODE 141 with epsilon 0.05910858963408712
# Episode:  141 , terminated with Reward  152.0
# Time elapsed during EPISODE 141: 80.50838875770569 seconds = 1.342 minutes
#
# Training on EPISODE 142 with epsilon 0.05792641784140538
# Episode:  142 , terminated with Reward  144.0
# Time elapsed during EPISODE 142: 86.60352659225464 seconds = 1.443 minutes
#
# Training on EPISODE 143 with epsilon 0.05676788948457727
# Episode:  143 , terminated with Reward  324.0
# Time elapsed during EPISODE 143: 173.66838788986206 seconds = 2.894 minutes
#
# Training on EPISODE 144 with epsilon 0.055632531694885724
# Episode:  144 , terminated with Reward  128.0
# Time elapsed during EPISODE 144: 66.71774744987488 seconds = 1.112 minutes
#
# Training on EPISODE 145 with epsilon 0.054519881060988006
# Episode:  145 , terminated with Reward  477.0
# Time elapsed during EPISODE 145: 255.12032461166382 seconds = 4.252 minutes
#
# Training on EPISODE 146 with epsilon 0.05342948343976824
# Time elapsed during EPISODE 146: 263.77462697029114 seconds = 4.396 minutes
#
# Training on EPISODE 147 with epsilon 0.052360893770972874
# Episode:  147 , terminated with Reward  103.0
# Time elapsed during EPISODE 147: 59.992865562438965 seconds = 1.0 minutes
#
# Training on EPISODE 148 with epsilon 0.05131367589555342
# Episode:  148 , terminated with Reward  344.0
# Time elapsed during EPISODE 148: 186.30578756332397 seconds = 3.105 minutes
#
# Training on EPISODE 149 with epsilon 0.05028740237764235
# Episode:  149 , terminated with Reward  38.0
# Time elapsed during EPISODE 149: 19.822359323501587 seconds = 0.33 minutes
#
# Training on EPISODE 150 with epsilon 0.0492816543300895
# Episode:  150 , terminated with Reward  415.0
# Time elapsed during EPISODE 150: 230.31813836097717 seconds = 3.839 minutes
#
# Training on EPISODE 151 with epsilon 0.04829602124348771
# Episode:  151 , terminated with Reward  198.0
# Time elapsed during EPISODE 151: 111.55763936042786 seconds = 1.859 minutes
#
# Training on EPISODE 152 with epsilon 0.04733010081861796
# Time elapsed during EPISODE 152: 322.2083570957184 seconds = 5.37 minutes
#
# Training on EPISODE 153 with epsilon 0.0463834988022456
# Episode:  153 , terminated with Reward  109.0
# Time elapsed during EPISODE 153: 68.78426218032837 seconds = 1.146 minutes
#
# Training on EPISODE 154 with epsilon 0.04545582882620069
# Time elapsed during EPISODE 154: 272.42215061187744 seconds = 4.54 minutes
#
# Training on EPISODE 155 with epsilon 0.04454671224967667
# Time elapsed during EPISODE 155: 275.87131357192993 seconds = 4.598 minutes
#
# Training on EPISODE 156 with epsilon 0.043655778004683135
# Episode:  156 , terminated with Reward  49.0
# Time elapsed during EPISODE 156: 26.143534183502197 seconds = 0.436 minutes
#
# Training on EPISODE 157 with epsilon 0.04278266244458947
# Episode:  157 , terminated with Reward  450.0
# Time elapsed during EPISODE 157: 282.326553106308 seconds = 4.705 minutes
#
# Training on EPISODE 158 with epsilon 0.04192700919569768
# Episode:  158 , terminated with Reward  158.0
# Time elapsed during EPISODE 158: 107.93627834320068 seconds = 1.799 minutes
#
# Training on EPISODE 159 with epsilon 0.04108846901178373
# Episode:  159 , terminated with Reward  197.0
# Time elapsed during EPISODE 159: 120.30732727050781 seconds = 2.005 minutes
#
# Training on EPISODE 160 with epsilon 0.04026669963154805
# Episode:  160 , terminated with Reward  174.0
# Time elapsed during EPISODE 160: 98.64843463897705 seconds = 1.644 minutes
#
# Training on EPISODE 161 with epsilon 0.03946136563891709
# Episode:  161 , terminated with Reward  170.0
# Time elapsed during EPISODE 161: 96.6398983001709 seconds = 1.611 minutes
#
# Training on EPISODE 162 with epsilon 0.03867213832613875
# Time elapsed during EPISODE 162: 239.43867087364197 seconds = 3.991 minutes
#
# Training on EPISODE 163 with epsilon 0.037898695559615975
# Episode:  163 , terminated with Reward  33.0
# Time elapsed during EPISODE 163: 7.1728599071502686 seconds = 0.12 minutes
#
# Training on EPISODE 164 with epsilon 0.03714072164842366
# Time elapsed during EPISODE 164: 163.34189081192017 seconds = 2.722 minutes
#
# Training on EPISODE 165 with epsilon 0.03639790721545518
# Time elapsed during EPISODE 165: 126.83450174331665 seconds = 2.114 minutes
#
# Training on EPISODE 166 with epsilon 0.035669949071146075
# Episode:  166 , terminated with Reward  162.0
# Time elapsed during EPISODE 166: 37.57010221481323 seconds = 0.626 minutes
#
# Training on EPISODE 167 with epsilon 0.034956550089723155
# Time elapsed during EPISODE 167: 137.3826231956482 seconds = 2.29 minutes
#
# Training on EPISODE 168 with epsilon 0.03425741908792869
# Time elapsed during EPISODE 168: 135.70191860198975 seconds = 2.262 minutes
#
# Training on EPISODE 169 with epsilon 0.03357227070617012
# Episode:  169 , terminated with Reward  258.0
# Time elapsed during EPISODE 169: 70.69074416160583 seconds = 1.178 minutes
#
# Training on EPISODE 170 with epsilon 0.032900825292046715
# Episode:  170 , terminated with Reward  480.0
# Time elapsed during EPISODE 170: 140.68917775154114 seconds = 2.345 minutes
#
# Training on EPISODE 171 with epsilon 0.03224280878620578
# Episode:  171 , terminated with Reward  121.0
# Time elapsed during EPISODE 171: 34.800901651382446 seconds = 0.58 minutes
#
# Training on EPISODE 172 with epsilon 0.031597952610481664
# Episode:  172 , terminated with Reward  137.0
# Time elapsed during EPISODE 172: 40.98155069351196 seconds = 0.683 minutes
#
# Training on EPISODE 173 with epsilon 0.03096599355827203
# Episode:  173 , terminated with Reward  104.0
# Time elapsed during EPISODE 173: 31.959472179412842 seconds = 0.533 minutes
#
# Training on EPISODE 174 with epsilon 0.030346673687106588
# Episode:  174 , terminated with Reward  161.0
# Time elapsed during EPISODE 174: 51.07754445075989 seconds = 0.851 minutes
#
# Training on EPISODE 175 with epsilon 0.029739740213364455
# Episode:  175 , terminated with Reward  146.0
# Time elapsed during EPISODE 175: 44.7444121837616 seconds = 0.746 minutes
#
# Training on EPISODE 176 with epsilon 0.029144945409097164
# Episode:  176 , terminated with Reward  16.0
# Time elapsed during EPISODE 176: 4.526810169219971 seconds = 0.075 minutes
#
# Training on EPISODE 177 with epsilon 0.02856204650091522
# Episode:  177 , terminated with Reward  201.0
# Time elapsed during EPISODE 177: 61.54115390777588 seconds = 1.026 minutes
#
# Training on EPISODE 178 with epsilon 0.027990805570896914
# Episode:  178 , terminated with Reward  205.0
# Time elapsed during EPISODE 178: 63.3569233417511 seconds = 1.056 minutes
#
# Training on EPISODE 179 with epsilon 0.027430989459478975
# Episode:  179 , terminated with Reward  118.0
# Time elapsed during EPISODE 179: 36.6687285900116 seconds = 0.611 minutes
#
# Training on EPISODE 180 with epsilon 0.026882369670289397
# Episode:  180 , terminated with Reward  227.0
# Time elapsed during EPISODE 180: 74.04535937309265 seconds = 1.234 minutes
#
# Training on EPISODE 181 with epsilon 0.026344722276883607
# Episode:  181 , terminated with Reward  80.0
# Time elapsed during EPISODE 181: 24.03494691848755 seconds = 0.401 minutes
#
# Training on EPISODE 182 with epsilon 0.025817827831345935
# Episode:  182 , terminated with Reward  122.0
# Time elapsed during EPISODE 182: 39.46751642227173 seconds = 0.658 minutes
#
# Training on EPISODE 183 with epsilon 0.025301471274719014
# Episode:  183 , terminated with Reward  346.0
# Time elapsed during EPISODE 183: 109.5039234161377 seconds = 1.825 minutes
#
# Training on EPISODE 184 with epsilon 0.024795441849224633
# Time elapsed during EPISODE 184: 153.98184037208557 seconds = 2.566 minutes
#
# Training on EPISODE 185 with epsilon 0.02429953301224014
# Time elapsed during EPISODE 185: 152.15403628349304 seconds = 2.536 minutes
#
# Training on EPISODE 186 with epsilon 0.02381354235199534
# Episode:  186 , terminated with Reward  445.0
# Time elapsed during EPISODE 186: 139.59829592704773 seconds = 2.327 minutes
#
# Training on EPISODE 187 with epsilon 0.02333727150495543
# Episode:  187 , terminated with Reward  317.0
# Time elapsed during EPISODE 187: 96.1658091545105 seconds = 1.603 minutes
#
# Training on EPISODE 188 with epsilon 0.02287052607485632
# Episode:  188 , terminated with Reward  105.0
# Time elapsed during EPISODE 188: 30.43318009376526 seconds = 0.507 minutes
#
# Training on EPISODE 189 with epsilon 0.022413115553359196
# Episode:  189 , terminated with Reward  97.0
# Time elapsed during EPISODE 189: 26.689077854156494 seconds = 0.445 minutes
#
# Training on EPISODE 190 with epsilon 0.021964853242292012
# Episode:  190 , terminated with Reward  388.0
# Time elapsed during EPISODE 190: 108.55634331703186 seconds = 1.809 minutes
#
# Training on EPISODE 191 with epsilon 0.02152555617744617
# Episode:  191 , terminated with Reward  132.0
# Time elapsed during EPISODE 191: 37.08939027786255 seconds = 0.618 minutes
#
# Training on EPISODE 192 with epsilon 0.021095045053897248
# Episode:  192 , terminated with Reward  209.0
# Time elapsed during EPISODE 192: 58.600735664367676 seconds = 0.977 minutes
#
# Training on EPISODE 193 with epsilon 0.020673144152819303
# Episode:  193 , terminated with Reward  145.0
# Time elapsed during EPISODE 193: 43.16135382652283 seconds = 0.719 minutes
#
# Training on EPISODE 194 with epsilon 0.02025968126976292
# Episode:  194 , terminated with Reward  133.0
# Time elapsed during EPISODE 194: 36.97302174568176 seconds = 0.616 minutes
#
# Training on EPISODE 195 with epsilon 0.01985448764436766
# Episode:  195 , terminated with Reward  194.0
# Time elapsed during EPISODE 195: 55.420021057128906 seconds = 0.924 minutes
#
# Training on EPISODE 196 with epsilon 0.019457397891480308
# Episode:  196 , terminated with Reward  126.0
# Time elapsed during EPISODE 196: 36.071325063705444 seconds = 0.601 minutes
#
# Training on EPISODE 197 with epsilon 0.0190682499336507
# Episode:  197 , terminated with Reward  133.0
# Time elapsed during EPISODE 197: 37.91139626502991 seconds = 0.632 minutes
#
# Training on EPISODE 198 with epsilon 0.018686884934977686
# Episode:  198 , terminated with Reward  228.0
# Time elapsed during EPISODE 198: 66.69478297233582 seconds = 1.112 minutes
#
# Training on EPISODE 199 with epsilon 0.01831314723627813
# Episode:  199 , terminated with Reward  254.0
# Time elapsed during EPISODE 199: 80.71134376525879 seconds = 1.345 minutes
#
# Training on EPISODE 200 with epsilon 0.017946884291552567
# Episode:  200 , terminated with Reward  103.0
# Time elapsed during EPISODE 200: 31.357676029205322 seconds = 0.523 minutes
#
# Training on EPISODE 201 with epsilon 0.017587946605721515
# Episode:  201 , terminated with Reward  210.0
# Time elapsed during EPISODE 201: 67.179372549057 seconds = 1.12 minutes
#
# Training on EPISODE 202 with epsilon 0.017236187673607083
# Episode:  202 , terminated with Reward  326.0
# Time elapsed during EPISODE 202: 114.9298825263977 seconds = 1.915 minutes
#
# Training on EPISODE 203 with epsilon 0.016891463920134943
# Episode:  203 , terminated with Reward  138.0
# Time elapsed during EPISODE 203: 44.88741898536682 seconds = 0.748 minutes
#
# Training on EPISODE 204 with epsilon 0.016553634641732245
# Episode:  204 , terminated with Reward  345.0
# Time elapsed during EPISODE 204: 111.4488742351532 seconds = 1.857 minutes
#
# Training on EPISODE 205 with epsilon 0.0162225619488976
# Episode:  205 , terminated with Reward  404.0
# Time elapsed during EPISODE 205: 135.3127875328064 seconds = 2.255 minutes
#
# Training on EPISODE 206 with epsilon 0.015898110709919647
# Episode:  206 , terminated with Reward  188.0
# Time elapsed during EPISODE 206: 60.31417179107666 seconds = 1.005 minutes
#
# Training on EPISODE 207 with epsilon 0.015580148495721254
# Episode:  207 , terminated with Reward  250.0
# Time elapsed during EPISODE 207: 80.24838662147522 seconds = 1.337 minutes
#
# Training on EPISODE 208 with epsilon 0.015268545525806828
# Episode:  208 , terminated with Reward  162.0
# Time elapsed during EPISODE 208: 51.61508560180664 seconds = 0.86 minutes
#
# Training on EPISODE 209 with epsilon 0.014963174615290691
# Episode:  209 , terminated with Reward  153.0
# Time elapsed during EPISODE 209: 50.035802364349365 seconds = 0.834 minutes
#
# Training on EPISODE 210 with epsilon 0.014663911122984877
# Episode:  210 , terminated with Reward  472.0
# Time elapsed during EPISODE 210: 155.46144771575928 seconds = 2.591 minutes
#
# Training on EPISODE 211 with epsilon 0.01437063290052518
# Episode:  211 , terminated with Reward  135.0
# Time elapsed during EPISODE 211: 44.73418378829956 seconds = 0.746 minutes
#
# Training on EPISODE 212 with epsilon 0.014083220242514675
# Episode:  212 , terminated with Reward  272.0
# Time elapsed during EPISODE 212: 91.00988388061523 seconds = 1.517 minutes
#
# Training on EPISODE 213 with epsilon 0.013801555837664382
# Episode:  213 , terminated with Reward  235.0
# Time elapsed during EPISODE 213: 77.51420569419861 seconds = 1.292 minutes
#
# Training on EPISODE 214 with epsilon 0.013525524720911095
# Episode:  214 , terminated with Reward  463.0
# Time elapsed during EPISODE 214: 159.05315375328064 seconds = 2.651 minutes
#
# Training on EPISODE 215 with epsilon 0.013255014226492874
# Episode:  215 , terminated with Reward  119.0
# Time elapsed during EPISODE 215: 39.45200872421265 seconds = 0.658 minutes
#
# Training on EPISODE 216 with epsilon 0.012989913941963017
# Episode:  216 , terminated with Reward  131.0
# Time elapsed during EPISODE 216: 42.96990180015564 seconds = 0.716 minutes
#
# Training on EPISODE 217 with epsilon 0.012730115663123756
# Episode:  217 , terminated with Reward  129.0
# Time elapsed during EPISODE 217: 44.442678928375244 seconds = 0.741 minutes
#
# Training on EPISODE 218 with epsilon 0.012475513349861281
# Episode:  218 , terminated with Reward  121.0
# Time elapsed during EPISODE 218: 37.39342164993286 seconds = 0.623 minutes
#
# Training on EPISODE 219 with epsilon 0.012226003082864055
# Episode:  219 , terminated with Reward  125.0
# Time elapsed during EPISODE 219: 40.43518018722534 seconds = 0.674 minutes
#
# Training on EPISODE 220 with epsilon 0.011981483021206774
# Time elapsed during EPISODE 220: 157.58387541770935 seconds = 2.626 minutes
#
# Training on EPISODE 221 with epsilon 0.011741853360782638
# Episode:  221 , terminated with Reward  60.0
# Time elapsed during EPISODE 221: 18.683159351348877 seconds = 0.311 minutes
#
# Training on EPISODE 222 with epsilon 0.011507016293566985
# Episode:  222 , terminated with Reward  176.0
# Time elapsed during EPISODE 222: 53.3194854259491 seconds = 0.889 minutes
#
# Training on EPISODE 223 with epsilon 0.011276875967695645
# Episode:  223 , terminated with Reward  147.0
# Time elapsed during EPISODE 223: 44.911396503448486 seconds = 0.749 minutes
#
# Training on EPISODE 224 with epsilon 0.011051338448341731
# Episode:  224 , terminated with Reward  178.0
# Time elapsed during EPISODE 224: 55.30728363990784 seconds = 0.922 minutes
#
# Training on EPISODE 225 with epsilon 0.010830311679374895
# Episode:  225 , terminated with Reward  101.0
# Time elapsed during EPISODE 225: 31.611773014068604 seconds = 0.527 minutes
#
# Training on EPISODE 226 with epsilon 0.010613705445787398
# Episode:  226 , terminated with Reward  112.0
# Time elapsed during EPISODE 226: 34.69119191169739 seconds = 0.578 minutes
#
# Training on EPISODE 227 with epsilon 0.01040143133687165
# Episode:  227 , terminated with Reward  119.0
# Time elapsed during EPISODE 227: 36.300381898880005 seconds = 0.605 minutes
#
# Training on EPISODE 228 with epsilon 0.010193402710134216
# Episode:  228 , terminated with Reward  154.0
# Time elapsed during EPISODE 228: 47.81714129447937 seconds = 0.797 minutes
#
# Training on EPISODE 229 with epsilon 0.009989534655931531
# Time elapsed during EPISODE 229: 171.14071345329285 seconds = 2.852 minutes
#
# Training on EPISODE 230 with epsilon 0.009989534655931531
# Episode:  230 , terminated with Reward  418.0
# Time elapsed during EPISODE 230: 150.9280743598938 seconds = 2.515 minutes
#
# Training on EPISODE 231 with epsilon 0.009989534655931531
# Episode:  231 , terminated with Reward  195.0
# Time elapsed during EPISODE 231: 66.35069870948792 seconds = 1.106 minutes
#
# Training on EPISODE 232 with epsilon 0.009989534655931531
# Episode:  232 , terminated with Reward  142.0
# Time elapsed during EPISODE 232: 48.90537643432617 seconds = 0.815 minutes
#
# Training on EPISODE 233 with epsilon 0.009989534655931531
# Episode:  233 , terminated with Reward  117.0
# Time elapsed during EPISODE 233: 37.843305587768555 seconds = 0.631 minutes
#
# Training on EPISODE 234 with epsilon 0.009989534655931531
# Episode:  234 , terminated with Reward  142.0
# Time elapsed during EPISODE 234: 46.85744047164917 seconds = 0.781 minutes
#
# Training on EPISODE 235 with epsilon 0.009989534655931531
# Episode:  235 , terminated with Reward  371.0
# Time elapsed during EPISODE 235: 130.76852202415466 seconds = 2.179 minutes
#
# Training on EPISODE 236 with epsilon 0.009989534655931531
# Episode:  236 , terminated with Reward  198.0
# Time elapsed during EPISODE 236: 74.67881226539612 seconds = 1.245 minutes
#
# Training on EPISODE 237 with epsilon 0.009989534655931531
# Time elapsed during EPISODE 237: 188.0512568950653 seconds = 3.134 minutes
#
# Training on EPISODE 238 with epsilon 0.009989534655931531
# Episode:  238 , terminated with Reward  141.0
# Time elapsed during EPISODE 238: 55.18164277076721 seconds = 0.92 minutes
#
# Training on EPISODE 239 with epsilon 0.009989534655931531
# Episode:  239 , terminated with Reward  139.0
# Time elapsed during EPISODE 239: 56.75959372520447 seconds = 0.946 minutes
#
# Training on EPISODE 240 with epsilon 0.009989534655931531
